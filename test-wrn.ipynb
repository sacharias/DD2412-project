# %%
# %load_ext autoreload
# %autoreload 2

import torch
from torchsummary import summary
from fixmatch import models
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
wrn = models.WRN(num_classes=10)
summary(wrn, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 16, 32, 32]             432
#        BatchNorm2d-2           [-1, 16, 32, 32]              32
#          LeakyReLU-3           [-1, 16, 32, 32]               0
#             Conv2d-4           [-1, 32, 32, 32]           4,608
#        BatchNorm2d-5           [-1, 32, 32, 32]              64
#          LeakyReLU-6           [-1, 32, 32, 32]               0
#             Conv2d-7           [-1, 32, 32, 32]           9,216
#             Conv2d-8           [-1, 32, 32, 32]             512
#      ResidualBlock-9           [-1, 32, 32, 32]               0
#       BatchNorm2d-10           [-1, 32, 32, 32]              64
#         LeakyReLU-11           [-1, 32, 32, 32]               0
#            Conv2d-12           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-13           [-1, 32, 32, 32]              64
# ...
